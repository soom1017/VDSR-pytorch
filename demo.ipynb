# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/VDSR'

# %%
# %cd VDSR-pytorch/
# Out:
# /content/drive/MyDrive/Colab Notebooks/VDSR/VDSR-pytorch

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 11.2 MB 4.4 MB/s
# ...
#      |████████████████████████████████| 4.3 MB 31.9 MB/s
# ERROR: Could not find a version that satisfies the requirement python==3.9.10 (from versions: none)
# ERROR: No matching distribution found for python==3.9.10

# %%
# !python3 src/train.py
# Out:
# Train Model for Scale Factor x2
# Epoch 1 of 40 >>>
# 100% 5/5 [00:04<00:00,  1.15it/s]
# 100% 5/5 [00:03<00:00,  1.27it/s]
# Training PSNR: 27.774
# Epoch 2 of 40 >>>
# 100% 5/5 [00:03<00:00,  1.27it/s]
# 100% 5/5 [00:04<00:00,  1.24it/s]
# Training PSNR: 27.181
# Epoch 3 of 40 >>>
# 100% 5/5 [00:04<00:00,  1.24it/s]
# 100% 5/5 [00:04<00:00,  1.22it/s]
# Training PSNR: 27.506
# Epoch 4 of 40 >>>
# 100% 5/5 [00:04<00:00,  1.22it/s]
# 100% 5/5 [00:04<00:00,  1.20it/s]
# Training PSNR: 27.480
# Epoch 5 of 40 >>>
# 100% 5/5 [00:04<00:00,  1.22it/s]
# 100% 5/5 [00:04<00:00,  1.21it/s]
# Training PSNR: 27.691
# Epoch 6 of 40 >>>
# 100% 5/5 [00:04<00:00,  1.20it/s]
# 100% 5/5 [00:04<00:00,  1.22it/s]
# Training PSNR: 27.464
# Epoch 7 of 40 >>>
# 100% 5/5 [00:04<00:00,  1.22it/s]
# 100% 5/5 [00:04<00:00,  1.24it/s]
# Training PSNR: 27.539
# Epoch 8 of 40 >>>
# 100% 5/5 [00:03<00:00,  1.26it/s]
# 100% 5/5 [00:03<00:00,  1.28it/s]
# Training PSNR: 27.458
# Epoch 9 of 40 >>>
# ...
